# %% [markdown]
# ## Linear Search

# %%
# Linear Search 

# Brute Force

def linear_search(arr: list, item:int):
    for i in range(len(arr)):
        if arr[i] == item:
            return i
    
    return -1

# %%
arrary = [87,9,45,74,14,52,6,5,48,45,2,33,4,8,]

linear_search(arrary,77)
# Out:
# -1

# %% [markdown]
# ## Binary Search

# %%
# Sorted Array

def binary_search(arr, low, high, item):
    if low <= high:
        mid = low + high //2
        if arr[mid] == item:
            return mid
        elif arr[mid] > item:
            return binary_search(arr, low, mid-1, item)
        else:
            return binary_search(arr, mid-1,high,item)
    else:
        return -1

# %%
arr =[5,7,17,19,22,29,38,49,56,68,79,85,97]

binary_search(arr,0,len(arr)-1,38)
# Out:
# 6

# %%
##  Check whether the given array is sorted or Not.

def is_sorted(arr):
    for i in range(len(arr)-1):
        if arr[i] > arr[i+1]:
            return False
    return True

arr = [1,2,6,8,19,20,25,84,94]

is_sorted(arr)
# Out:
# True

# %% [markdown]
# ## Bubble Sort

# %%
def bubble_sort(arr):
    for i in range(len(arr) -1):
        flag = 0
        for j in range(len(arr) - 1 - i):
            if arr[j] > arr[j+1]:
                arr[j],arr[j+1] = arr[j+1],arr[j]
                flag = 1
        if flag == 0:
            break
                
    return arr


arr=[6,1,6,3,4,8]
bubble_sort(arr)
# Out:
# [1, 3, 4, 6, 6, 8]

# %% [markdown]
# ## Selection Sort

# %%
def selection_sort(arr):
    for i in range(len(arr)):
        min_index = i
        for j in range(i + 1, len(arr)):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i],arr[min_index] = arr[min_index],arr[i]
    return arr


arr=[8,9,4,5,61,2]
selection_sort(arr)
# Out:
# [2, 4, 5, 8, 9, 61]

# %% [markdown]
# ## Merge Sort

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    
    return merge(left,right)


def merge(left,right):
    result = []
    i = j = 0
    
    while i < len(left) and j <len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    
    return result

merge_sort([8,9,7,45,6,1,25,4,8,78])
# Out:
# [1, 4, 6, 7, 8, 8, 9, 25, 45, 78]
